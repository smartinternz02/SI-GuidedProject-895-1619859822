# %% [markdown]
# # working with iris data set

# %%
import seaborn as sns

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
sns.heatmap(iris.corr(),annot=True)

# %% [raw]
# INSIGHTS GRABBED FROM THE HEATMAP
#
# 1) sepal_length, petal_length
# 2) sepal_length, petal_width
# 3) petal_length, sepal_length
# 4) petal_length, petal_width
# 5) petal_width, sepal_length
# 6) petal_width, petal_length    are positively correlated (+ve and greater than 0.6) thus should be considered for data analysis

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)

# %% [raw]
# insight grabbed:
#
# 1)the distribution is concentrated in the median range of petal and sepal lengths
# 2)many of the flowers have median petal and sepal lengths

# %%
sns.scatterplot(x='sepal_length',y='petal_width',data=iris)

# %% [raw]
# insights grabbed:
#
# 1) the petal width increases with increase in sepal length noticably after the median range of length

# %%
sns.scatterplot(x='petal_length',y='sepal_length',data=iris)

# %% [raw]
# insights grabbed:
#
# 1) the sepal length is concentrated at 5.0  for the petal lengths varying from 1-2

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=iris)

# %%
sns.scatterplot(x='petal_width',y='sepal_length',data=iris)

# %%
sns.scatterplot(x='petal_width',y='petal_length',data=iris)

# %%
sns.lineplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.lineplot(x='sepal_length',y='petal_width',data=iris)

# %%
sns.lineplot(x='petal_length',y='sepal_length',data=iris)

# %%
sns.lineplot(x='petal_length',y='petal_width',data=iris)

# %% [raw]
# insights grabbed:
#
# 1) the petal length between 2-3 is directly proportional to petal width

# %%
sns.lineplot(x='petal_width',y='sepal_length',data=iris)

# %% [raw]
# insights grabbed:
#
# 1)the longest sepals can be found for those  having  petal_widths  between 2.1-2.4

# %%
sns.lineplot(x='petal_width',y='petal_length',data=iris)

# %% [raw]
# insights grabbed:
#
# 1)the longest petal have the petal_width as 2.3-2.4 on an average

# %%
sns.distplot(iris['petal_length'])

# %%
sns.distplot(iris['sepal_length'])

# %%
sns.distplot(iris['petal_width'])

# %%
sns.distplot(iris['sepal_width'])

# %%
sns.barplot(x='petal_length',y='species',data=iris)

# %%
sns.barplot(x='sepal_length',y='species',data=iris)

# %%
sns.barplot(x='petal_width',y='species',data=iris)

# %%
sns.barplot(x='sepal_width',y='species',data=iris)

# %% [raw]
# INSIGHTS GRABBED FROM ALL THE ABOVE BAR PLOTS:
#
# 1) VIRGINICA SPECIES HAVE: LONGEST PETALS,SEPALS
#                            BROAD PETALS,
#                            JUST RIGHT SEPALS(WIDTH)
# 2) SETOSA SPECIES HAVE: SHORTEST PETALS,SEPALS
#                         NARROW PETALS,
#                         BROAD SEPALS(WIDTH)
# 3) VERSICOLOR HAVE: JUST RIGHT LENGTH OF PETALS,SEPALS,
#                     JUST RIGHT WIDTH OF PETALS,
#                     NARROW SEPALS(WIDTH)

# %%
sns.pairplot(iris)

# %%
sns.catplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.catplot(x='sepal_length',y='petal_width',data=iris)

# %%
sns.catplot(x='petal_length',y='sepal_length',data=iris)

# %%
sns.catplot(x='petal_length',y='petal_width',data=iris)

# %%
sns.catplot(x='petal_width',y='sepal_length',data=iris)

# %%
sns.catplot(x='petal_width',y='petal_length',data=iris)

# %%
sns.boxplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.boxplot(x='sepal_length',y='petal_width',data=iris)

# %%
sns.boxplot(x='petal_length',y='sepal_length',data=iris)

# %%
sns.boxplot(x='petal_length',y='petal_width',data=iris)

# %%
sns.boxplot(x='petal_width',y='sepal_length',data=iris)

# %%
#insights grabbed:
#the first quartile occurs at an average of 5.5-6.0 sepal length

# %%
sns.boxplot(x='petal_width',y='petal_length',data=iris)

# %%
#insights grabbed:
#many outlayers are present for the flowers having petal length 0.20
